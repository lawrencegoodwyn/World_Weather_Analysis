# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 741

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=b59aabc9521d19db86bc2f8be057498a"
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=b59aabc9521d19db86bc2f8be057498a

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
    # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
    # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
    # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                        "Lat": city_lat,
                        "Lng": city_lng,
                        "Max Temp": city_max_temp,
                        "Humidity": city_humidity,
                        "Cloudiness": city_clouds,
                        "Wind Speed": city_wind,
                        "Country": city_country,
                        "Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
    pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | kapaa
# Processing Record 3 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 4 of Set 1 | ucluelet
# Processing Record 5 of Set 1 | bluff
# Processing Record 6 of Set 1 | lorengau
# Processing Record 7 of Set 1 | pangnirtung
# Processing Record 8 of Set 1 | san jeronimo
# Processing Record 9 of Set 1 | panzhihua
# Processing Record 10 of Set 1 | vila franca do campo
# Processing Record 11 of Set 1 | margate
# Processing Record 12 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 1 | lusambo
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | qazvin
# Processing Record 17 of Set 1 | harer
# Processing Record 18 of Set 1 | bac lieu
# Processing Record 19 of Set 1 | shizunai
# Processing Record 20 of Set 1 | puerto ayora
# Processing Record 21 of Set 1 | barrow
# Processing Record 22 of Set 1 | meulaboh
# Processing Record 23 of Set 1 | atuona
# Processing Record 24 of Set 1 | hithadhoo
# Processing Record 25 of Set 1 | xai-xai
# Processing Record 26 of Set 1 | banda aceh
# Processing Record 27 of Set 1 | porto-vecchio
# Processing Record 28 of Set 1 | agirish
# Processing Record 29 of Set 1 | ushuaia
# Processing Record 30 of Set 1 | khatanga
# Processing Record 31 of Set 1 | marsa matruh
# Processing Record 32 of Set 1 | codrington
# Processing Record 33 of Set 1 | thompson
# Processing Record 34 of Set 1 | yellowknife
# Processing Record 35 of Set 1 | jamestown
# Processing Record 36 of Set 1 | banjar
# Processing Record 37 of Set 1 | galle
# Processing Record 38 of Set 1 | san isidro
# Processing Record 39 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 1 | fomboni
# Processing Record 41 of Set 1 | east london
# Processing Record 42 of Set 1 | bredasdorp
# Processing Record 43 of Set 1 | busselton
# Processing Record 44 of Set 1 | sao gabriel
# Processing Record 45 of Set 1 | laguna
# Processing Record 46 of Set 1 | mbandaka
# Processing Record 47 of Set 1 | bollene
# Processing Record 48 of Set 1 | zyryanovsk
# Processing Record 49 of Set 1 | kavieng
# Processing Record 50 of Set 1 | qaanaaq
# Processing Record 1 of Set 2 | georgetown
# Processing Record 2 of Set 2 | albany
# Processing Record 3 of Set 2 | hobart
# Processing Record 4 of Set 2 | hilo
# Processing Record 5 of Set 2 | okhotsk
# Processing Record 6 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 2 | kieta
# Processing Record 8 of Set 2 | tuktoyaktuk
# Processing Record 9 of Set 2 | salalah
# Processing Record 10 of Set 2 | new norfolk
# Processing Record 11 of Set 2 | port elizabeth
# Processing Record 12 of Set 2 | port alfred
# Processing Record 13 of Set 2 | lakselv
# Processing Record 14 of Set 2 | mount pleasant
# Processing Record 15 of Set 2 | doha
# Processing Record 16 of Set 2 | poum
# Processing Record 17 of Set 2 | dunedin
# Processing Record 18 of Set 2 | yen bai
# Processing Record 19 of Set 2 | mataura
# Processing Record 20 of Set 2 | weinan
# Processing Record 21 of Set 2 | katsuura
# Processing Record 22 of Set 2 | san angelo
# Processing Record 23 of Set 2 | am timan
# Processing Record 24 of Set 2 | cape town
# Processing Record 25 of Set 2 | isangel
# Processing Record 26 of Set 2 | saint anthony
# Processing Record 27 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 28 of Set 2 | kichera
# Processing Record 29 of Set 2 | kruisfontein
# Processing Record 30 of Set 2 | anadyr
# Processing Record 31 of Set 2 | vaini
# Processing Record 32 of Set 2 | pisco
# Processing Record 33 of Set 2 | tiksi
# Processing Record 34 of Set 2 | ashland
# Processing Record 35 of Set 2 | saint-michel-des-saints
# Processing Record 36 of Set 2 | pout
# Processing Record 37 of Set 2 | beringovskiy
# Processing Record 38 of Set 2 | tasiilaq
# Processing Record 39 of Set 2 | port macquarie
# Processing Record 40 of Set 2 | verkhnevilyuysk
# Processing Record 41 of Set 2 | lemesos
# City not found. Skipping...
# Processing Record 42 of Set 2 | kahului
# Processing Record 43 of Set 2 | kaitangata
# Processing Record 44 of Set 2 | luderitz
# Processing Record 45 of Set 2 | hobyo
# Processing Record 46 of Set 2 | port lincoln
# Processing Record 47 of Set 2 | kurchum
# Processing Record 48 of Set 2 | castro
# Processing Record 49 of Set 2 | viedma
# Processing Record 50 of Set 2 | lagoa
# Processing Record 1 of Set 3 | dikson
# Processing Record 2 of Set 3 | chuy
# Processing Record 3 of Set 3 | torbay
# Processing Record 4 of Set 3 | portland
# Processing Record 5 of Set 3 | kodiak
# Processing Record 6 of Set 3 | prado
# Processing Record 7 of Set 3 | alice town
# Processing Record 8 of Set 3 | makkaveyevo
# Processing Record 9 of Set 3 | bambous virieux
# Processing Record 10 of Set 3 | scottsburgh
# City not found. Skipping...
# Processing Record 11 of Set 3 | carnarvon
# Processing Record 12 of Set 3 | antofagasta
# Processing Record 13 of Set 3 | taoudenni
# Processing Record 14 of Set 3 | collie
# Processing Record 15 of Set 3 | akureyri
# Processing Record 16 of Set 3 | chokurdakh
# Processing Record 17 of Set 3 | tabou
# Processing Record 18 of Set 3 | fortuna
# Processing Record 19 of Set 3 | avarua
# Processing Record 20 of Set 3 | saint george
# Processing Record 21 of Set 3 | nouadhibou
# Processing Record 22 of Set 3 | puerto leguizamo
# Processing Record 23 of Set 3 | haines junction
# Processing Record 24 of Set 3 | nikolskoye
# Processing Record 25 of Set 3 | plaster rock
# Processing Record 26 of Set 3 | veisiejai
# Processing Record 27 of Set 3 | avera
# Processing Record 28 of Set 3 | linhai
# Processing Record 29 of Set 3 | dzhusaly
# City not found. Skipping...
# Processing Record 30 of Set 3 | ovsyanka
# Processing Record 31 of Set 3 | clarksburg
# Processing Record 32 of Set 3 | novoagansk
# Processing Record 33 of Set 3 | hermanus
# Processing Record 34 of Set 3 | stamsund
# City not found. Skipping...
# Processing Record 35 of Set 3 | broken hill
# Processing Record 36 of Set 3 | buchanan
# Processing Record 37 of Set 3 | ilulissat
# Processing Record 38 of Set 3 | caravelas
# Processing Record 39 of Set 3 | ribeira grande
# Processing Record 40 of Set 3 | cidreira
# Processing Record 41 of Set 3 | lincoln
# Processing Record 42 of Set 3 | geraldton
# Processing Record 43 of Set 3 | cayenne
# Processing Record 44 of Set 3 | lashio
# Processing Record 45 of Set 3 | kashi
# Processing Record 46 of Set 3 | constitucion
# Processing Record 47 of Set 3 | bhinmal
# Processing Record 48 of Set 3 | hami
# Processing Record 49 of Set 3 | iralaya
# Processing Record 50 of Set 3 | bossembele
# City not found. Skipping...
# Processing Record 1 of Set 4 | karratha
# Processing Record 2 of Set 4 | dhaulpur
# Processing Record 3 of Set 4 | bereda
# Processing Record 4 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 4 | san jose
# Processing Record 6 of Set 4 | villazon
# Processing Record 7 of Set 4 | haapiti
# Processing Record 8 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 4 | trinidad
# Processing Record 10 of Set 4 | iqaluit
# Processing Record 11 of Set 4 | tyret pervaya
# Processing Record 12 of Set 4 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 13 of Set 4 | clyde river
# Processing Record 14 of Set 4 | qostanay
# Processing Record 15 of Set 4 | arraial do cabo
# Processing Record 16 of Set 4 | sisimiut
# Processing Record 17 of Set 4 | dalvik
# Processing Record 18 of Set 4 | bani
# Processing Record 19 of Set 4 | tete
# Processing Record 20 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 4 | necochea
# Processing Record 22 of Set 4 | lebu
# Processing Record 23 of Set 4 | upernavik
# Processing Record 24 of Set 4 | neiafu
# Processing Record 25 of Set 4 | zhigansk
# Processing Record 26 of Set 4 | klaksvik
# Processing Record 27 of Set 4 | sao filipe
# Processing Record 28 of Set 4 | esperance
# Processing Record 29 of Set 4 | almaznyy
# Processing Record 30 of Set 4 | champerico
# Processing Record 31 of Set 4 | florenville
# Processing Record 32 of Set 4 | havre-saint-pierre
# Processing Record 33 of Set 4 | provideniya
# Processing Record 34 of Set 4 | bethel
# Processing Record 35 of Set 4 | caraguatatuba
# Processing Record 36 of Set 4 | viseu
# Processing Record 37 of Set 4 | cabo san lucas
# Processing Record 38 of Set 4 | beloha
# Processing Record 39 of Set 4 | dali
# Processing Record 40 of Set 4 | rawson
# Processing Record 41 of Set 4 | iesolo
# Processing Record 42 of Set 4 | huarmey
# Processing Record 43 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 4 | korla
# Processing Record 45 of Set 4 | samana
# Processing Record 46 of Set 4 | coihaique
# Processing Record 47 of Set 4 | tazovskiy
# Processing Record 48 of Set 4 | ofaqim
# Processing Record 49 of Set 4 | saryshagan
# City not found. Skipping...
# Processing Record 50 of Set 4 | kiunga
# Processing Record 1 of Set 5 | limenaria
# Processing Record 2 of Set 5 | butaritari
# Processing Record 3 of Set 5 | sitka
# Processing Record 4 of Set 5 | airai
# Processing Record 5 of Set 5 | sibolga
# Processing Record 6 of Set 5 | pitimbu
# Processing Record 7 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 8 of Set 5 | puerto quijarro
# Processing Record 9 of Set 5 | mount gambier
# Processing Record 10 of Set 5 | viesca
# Processing Record 11 of Set 5 | zhanatas
# City not found. Skipping...
# Processing Record 12 of Set 5 | lensk
# Processing Record 13 of Set 5 | rocha
# Processing Record 14 of Set 5 | palu
# Processing Record 15 of Set 5 | tateyama
# Processing Record 16 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 17 of Set 5 | bara
# Processing Record 18 of Set 5 | basay
# Processing Record 19 of Set 5 | tessalit
# Processing Record 20 of Set 5 | lata
# Processing Record 21 of Set 5 | xingcheng
# Processing Record 22 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 5 | bon accord
# Processing Record 24 of Set 5 | carutapera
# Processing Record 25 of Set 5 | waw
# Processing Record 26 of Set 5 | kendari
# Processing Record 27 of Set 5 | vaitape
# Processing Record 28 of Set 5 | gat
# Processing Record 29 of Set 5 | narsaq
# Processing Record 30 of Set 5 | rio grande
# Processing Record 31 of Set 5 | marsabit
# Processing Record 32 of Set 5 | longyearbyen
# Processing Record 33 of Set 5 | kuhestan
# City not found. Skipping...
# Processing Record 34 of Set 5 | saskylakh
# Processing Record 35 of Set 5 | bengkulu
# Processing Record 36 of Set 5 | atar
# Processing Record 37 of Set 5 | san cristobal
# Processing Record 38 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 5 | moose jaw
# Processing Record 40 of Set 5 | sorland
# Processing Record 41 of Set 5 | san luis
# Processing Record 42 of Set 5 | ipixuna
# Processing Record 43 of Set 5 | shiyan
# Processing Record 44 of Set 5 | charters towers
# Processing Record 45 of Set 5 | nome
# Processing Record 46 of Set 5 | slave lake
# Processing Record 47 of Set 5 | husavik
# Processing Record 48 of Set 5 | mongo
# Processing Record 49 of Set 5 | santa maria
# Processing Record 50 of Set 5 | medveda
# Processing Record 1 of Set 6 | ouesso
# Processing Record 2 of Set 6 | ancud
# Processing Record 3 of Set 6 | faanui
# Processing Record 4 of Set 6 | arlit
# Processing Record 5 of Set 6 | sunndalsora
# Processing Record 6 of Set 6 | nadym
# Processing Record 7 of Set 6 | soledad
# Processing Record 8 of Set 6 | saint-philippe
# Processing Record 9 of Set 6 | north las vegas
# Processing Record 10 of Set 6 | tambovka
# Processing Record 11 of Set 6 | artyk
# City not found. Skipping...
# Processing Record 12 of Set 6 | ponta do sol
# Processing Record 13 of Set 6 | mimongo
# Processing Record 14 of Set 6 | ambilobe
# Processing Record 15 of Set 6 | auki
# Processing Record 16 of Set 6 | udachnyy
# Processing Record 17 of Set 6 | broome
# Processing Record 18 of Set 6 | winnemucca
# Processing Record 19 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 20 of Set 6 | spokane
# Processing Record 21 of Set 6 | fort nelson
# Processing Record 22 of Set 6 | jarjis
# City not found. Skipping...
# Processing Record 23 of Set 6 | college
# Processing Record 24 of Set 6 | mar del plata
# Processing Record 25 of Set 6 | te anau
# Processing Record 26 of Set 6 | shuyskoye
# Processing Record 27 of Set 6 | vardo
# Processing Record 28 of Set 6 | goderich
# Processing Record 29 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 30 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 31 of Set 6 | severnoye
# Processing Record 32 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 6 | phonhong
# Processing Record 34 of Set 6 | tebingtinggi
# Processing Record 35 of Set 6 | jiayuguan
# Processing Record 36 of Set 6 | villa guerrero
# Processing Record 37 of Set 6 | victoria
# Processing Record 38 of Set 6 | yaan
# Processing Record 39 of Set 6 | port blair
# Processing Record 40 of Set 6 | calabozo
# Processing Record 41 of Set 6 | raudeberg
# Processing Record 42 of Set 6 | ritchie
# Processing Record 43 of Set 6 | yar-sale
# Processing Record 44 of Set 6 | port hardy
# Processing Record 45 of Set 6 | vangaindrano
# Processing Record 46 of Set 6 | brasileia
# Processing Record 47 of Set 6 | ornes
# Processing Record 48 of Set 6 | fredericksburg
# Processing Record 49 of Set 6 | mount isa
# Processing Record 50 of Set 6 | pangody
# Processing Record 1 of Set 7 | ushtobe
# Processing Record 2 of Set 7 | muhos
# Processing Record 3 of Set 7 | kaura namoda
# Processing Record 4 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 5 of Set 7 | coquimbo
# Processing Record 6 of Set 7 | san patricio
# Processing Record 7 of Set 7 | wuhan
# Processing Record 8 of Set 7 | lavrentiya
# Processing Record 9 of Set 7 | alice springs
# Processing Record 10 of Set 7 | huari
# Processing Record 11 of Set 7 | vanavara
# Processing Record 12 of Set 7 | guiratinga
# Processing Record 13 of Set 7 | bulgan
# Processing Record 14 of Set 7 | neyshabur
# Processing Record 15 of Set 7 | touros
# Processing Record 16 of Set 7 | san quintin
# Processing Record 17 of Set 7 | san nicolas
# Processing Record 18 of Set 7 | severo-kurilsk
# Processing Record 19 of Set 7 | namatanai
# Processing Record 20 of Set 7 | kizema
# Processing Record 21 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 7 | san rafael
# Processing Record 23 of Set 7 | kenai
# Processing Record 24 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 25 of Set 7 | mehriz
# Processing Record 26 of Set 7 | mathbaria
# Processing Record 27 of Set 7 | jalu
# Processing Record 28 of Set 7 | izumo
# Processing Record 29 of Set 7 | imeni poliny osipenko
# Processing Record 30 of Set 7 | jinchang
# Processing Record 31 of Set 7 | tuatapere
# Processing Record 32 of Set 7 | tulun
# Processing Record 33 of Set 7 | ambon
# Processing Record 34 of Set 7 | henties bay
# Processing Record 35 of Set 7 | hamilton
# Processing Record 36 of Set 7 | eldikan
# City not found. Skipping...
# Processing Record 37 of Set 7 | koupela
# Processing Record 38 of Set 7 | dalbandin
# Processing Record 39 of Set 7 | mbour
# Processing Record 40 of Set 7 | mahebourg
# Processing Record 41 of Set 7 | bagdarin
# Processing Record 42 of Set 7 | cairns
# Processing Record 43 of Set 7 | aksu
# Processing Record 44 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 7 | skalistyy
# City not found. Skipping...
# Processing Record 46 of Set 7 | port moresby
# Processing Record 47 of Set 7 | lima
# Processing Record 48 of Set 7 | coahuayana
# Processing Record 49 of Set 7 | coari
# Processing Record 50 of Set 7 | asau
# Processing Record 1 of Set 8 | quelimane
# Processing Record 2 of Set 8 | maracacume
# Processing Record 3 of Set 8 | sumbawa
# City not found. Skipping...
# Processing Record 4 of Set 8 | grand gaube
# Processing Record 5 of Set 8 | woodend
# Processing Record 6 of Set 8 | kavaratti
# Processing Record 7 of Set 8 | dzilam gonzalez
# Processing Record 8 of Set 8 | biak
# Processing Record 9 of Set 8 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 10 of Set 8 | ostersund
# Processing Record 11 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 8 | el reno
# Processing Record 13 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 14 of Set 8 | nanyamba
# Processing Record 15 of Set 8 | mogadishu
# Processing Record 16 of Set 8 | nelson bay
# Processing Record 17 of Set 8 | harwich
# Processing Record 18 of Set 8 | tabuk
# Processing Record 19 of Set 8 | marsaxlokk
# Processing Record 20 of Set 8 | sibut
# Processing Record 21 of Set 8 | ituni
# City not found. Skipping...
# Processing Record 22 of Set 8 | mana
# Processing Record 23 of Set 8 | lang suan
# Processing Record 24 of Set 8 | pevek
# Processing Record 25 of Set 8 | saint-joseph
# Processing Record 26 of Set 8 | atikokan
# Processing Record 27 of Set 8 | kirakira
# Processing Record 28 of Set 8 | sao desiderio
# Processing Record 29 of Set 8 | talnakh
# Processing Record 30 of Set 8 | bad mergentheim
# Processing Record 31 of Set 8 | los llanos de aridane
# Processing Record 32 of Set 8 | kaka
# Processing Record 33 of Set 8 | quesnel
# Processing Record 34 of Set 8 | kaeo
# Processing Record 35 of Set 8 | mahaicony
# City not found. Skipping...
# Processing Record 36 of Set 8 | churapcha
# Processing Record 37 of Set 8 | ust-ilimsk
# Processing Record 38 of Set 8 | poindimie
# Processing Record 39 of Set 8 | pochutla
# Processing Record 40 of Set 8 | luwuk
# Processing Record 41 of Set 8 | leningradskiy
# Processing Record 42 of Set 8 | huaihua
# Processing Record 43 of Set 8 | abalak
# Processing Record 44 of Set 8 | souillac
# Processing Record 45 of Set 8 | ghanzi
# Processing Record 46 of Set 8 | sheregesh
# Processing Record 47 of Set 8 | waingapu
# Processing Record 48 of Set 8 | surgut
# Processing Record 49 of Set 8 | gualeguay
# Processing Record 50 of Set 8 | mecca
# Processing Record 1 of Set 9 | daru
# Processing Record 2 of Set 9 | shanghai
# Processing Record 3 of Set 9 | xuzhou
# Processing Record 4 of Set 9 | kungurtug
# Processing Record 5 of Set 9 | lingao
# Processing Record 6 of Set 9 | pilar
# Processing Record 7 of Set 9 | suntar
# Processing Record 8 of Set 9 | flinders
# Processing Record 9 of Set 9 | bassila
# Processing Record 10 of Set 9 | houma
# Processing Record 11 of Set 9 | half moon bay
# Processing Record 12 of Set 9 | zambezi
# Processing Record 13 of Set 9 | aklavik
# Processing Record 14 of Set 9 | port augusta
# Processing Record 15 of Set 9 | talesh
# City not found. Skipping...
# Processing Record 16 of Set 9 | namibe
# Processing Record 17 of Set 9 | pudozh
# Processing Record 18 of Set 9 | pahrump
# Processing Record 19 of Set 9 | jutai
# Processing Record 20 of Set 9 | yulara
# Processing Record 21 of Set 9 | banmo
# City not found. Skipping...
# Processing Record 22 of Set 9 | bandarbeyla
# Processing Record 23 of Set 9 | calbiga
# Processing Record 24 of Set 9 | yerbogachen
# Processing Record 25 of Set 9 | high level
# Processing Record 26 of Set 9 | uvira
# Processing Record 27 of Set 9 | vila velha
# Processing Record 28 of Set 9 | pospelikha
# Processing Record 29 of Set 9 | leshukonskoye
# Processing Record 30 of Set 9 | jacareacanga
# Processing Record 31 of Set 9 | inderborskiy
# City not found. Skipping...
# Processing Record 32 of Set 9 | oistins
# Processing Record 33 of Set 9 | nanortalik
# Processing Record 34 of Set 9 | bilibino
# Processing Record 35 of Set 9 | vidim
# Processing Record 36 of Set 9 | moron
# Processing Record 37 of Set 9 | bridlington
# Processing Record 38 of Set 9 | saldanha
# Processing Record 39 of Set 9 | liberal
# Processing Record 40 of Set 9 | hirara
# Processing Record 41 of Set 9 | leshan
# Processing Record 42 of Set 9 | araouane
# Processing Record 43 of Set 9 | la ronge
# Processing Record 44 of Set 9 | khagrachari
# City not found. Skipping...
# Processing Record 45 of Set 9 | kakogawa
# Processing Record 46 of Set 9 | santa cruz
# Processing Record 47 of Set 9 | fillmore
# Processing Record 48 of Set 9 | adrar
# Processing Record 49 of Set 9 | kaihua
# Processing Record 50 of Set 9 | zagar
# Processing Record 1 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 2 of Set 10 | makat
# Processing Record 3 of Set 10 | tabas
# Processing Record 4 of Set 10 | yermekeyevo
# Processing Record 5 of Set 10 | egvekinot
# Processing Record 6 of Set 10 | odesskoye
# Processing Record 7 of Set 10 | da lat
# Processing Record 8 of Set 10 | poso
# Processing Record 9 of Set 10 | bathsheba
# Processing Record 10 of Set 10 | uyemskiy
# Processing Record 11 of Set 10 | windhoek
# Processing Record 12 of Set 10 | la libertad
# Processing Record 13 of Set 10 | turki
# Processing Record 14 of Set 10 | bonavista
# Processing Record 15 of Set 10 | soyo
# Processing Record 16 of Set 10 | oranjemund
# Processing Record 17 of Set 10 | dohar
# Processing Record 18 of Set 10 | qui nhon
# Processing Record 19 of Set 10 | andros town
# Processing Record 20 of Set 10 | san antonio
# Processing Record 21 of Set 10 | merauke
# Processing Record 22 of Set 10 | den helder
# Processing Record 23 of Set 10 | yatou
# Processing Record 24 of Set 10 | severiano melo
# Processing Record 25 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 10 | kirovskiy
# Processing Record 27 of Set 10 | eshowe
# Processing Record 28 of Set 10 | canchungo
# Processing Record 29 of Set 10 | paamiut
# Processing Record 30 of Set 10 | naryan-mar
# Processing Record 31 of Set 10 | norman wells
# Processing Record 32 of Set 10 | ijaki
# City not found. Skipping...
# Processing Record 33 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 34 of Set 10 | sur
# Processing Record 35 of Set 10 | oktyabrskiy
# Processing Record 36 of Set 10 | morehead
# Processing Record 37 of Set 10 | vaxjo
# Processing Record 38 of Set 10 | kulhudhuffushi
# Processing Record 39 of Set 10 | batagay-alyta
# Processing Record 40 of Set 10 | dingle
# Processing Record 41 of Set 10 | alofi
# Processing Record 42 of Set 10 | carbonia
# Processing Record 43 of Set 10 | awbari
# Processing Record 44 of Set 10 | karaton
# Processing Record 45 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 46 of Set 10 | velikie luki
# City not found. Skipping...
# Processing Record 47 of Set 10 | hokitika
# Processing Record 48 of Set 10 | basyanovskiy
# City not found. Skipping...
# Processing Record 49 of Set 10 | kajaani
# Processing Record 50 of Set 10 | kidal
# Processing Record 1 of Set 11 | walvis bay
# Processing Record 2 of Set 11 | mosetse
# Processing Record 3 of Set 11 | itoman
# Processing Record 4 of Set 11 | livingstonia
# Processing Record 5 of Set 11 | manokwari
# Processing Record 6 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 7 of Set 11 | uwayl
# City not found. Skipping...
# Processing Record 8 of Set 11 | alyangula
# Processing Record 9 of Set 11 | lannion
# Processing Record 10 of Set 11 | esqueda
# Processing Record 11 of Set 11 | tak bai
# Processing Record 12 of Set 11 | le mans
# Processing Record 13 of Set 11 | acajutla
# Processing Record 14 of Set 11 | trat
# Processing Record 15 of Set 11 | hambantota
# Processing Record 16 of Set 11 | miranda de ebro
# Processing Record 17 of Set 11 | isiro
# Processing Record 18 of Set 11 | saint-leu
# Processing Record 19 of Set 11 | bongandanga
# Processing Record 20 of Set 11 | jahrom
# City not found. Skipping...
# Processing Record 21 of Set 11 | troitsko-pechorsk
# Processing Record 22 of Set 11 | sompeta
# Processing Record 23 of Set 11 | garowe
# Processing Record 24 of Set 11 | alpena
# Processing Record 25 of Set 11 | tucuman
# Processing Record 26 of Set 11 | elk plain
# Processing Record 27 of Set 11 | porto novo
# Processing Record 28 of Set 11 | guayape
# Processing Record 29 of Set 11 | buraydah
# Processing Record 30 of Set 11 | leh
# Processing Record 31 of Set 11 | mananjary
# Processing Record 32 of Set 11 | verkhoyansk
# Processing Record 33 of Set 11 | realeza
# Processing Record 34 of Set 11 | ola
# Processing Record 35 of Set 11 | sobolevo
# Processing Record 36 of Set 11 | uporovo
# Processing Record 37 of Set 11 | carballo
# Processing Record 38 of Set 11 | hasaki
# Processing Record 39 of Set 11 | banepa
# Processing Record 40 of Set 11 | jacqueville
# Processing Record 41 of Set 11 | cortona
# Processing Record 42 of Set 11 | wausau
# Processing Record 43 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 44 of Set 11 | san-pedro
# Processing Record 45 of Set 11 | edd
# Processing Record 46 of Set 11 | nantucket
# Processing Record 47 of Set 11 | mayumba
# Processing Record 48 of Set 11 | warman
# Processing Record 49 of Set 11 | akdepe
# Processing Record 50 of Set 11 | umm kaddadah
# Processing Record 1 of Set 12 | nizwa
# Processing Record 2 of Set 12 | khandyga
# Processing Record 3 of Set 12 | vila
# Processing Record 4 of Set 12 | karamadai
# Processing Record 5 of Set 12 | lianran
# Processing Record 6 of Set 12 | noumea
# Processing Record 7 of Set 12 | havelock
# Processing Record 8 of Set 12 | noshiro
# Processing Record 9 of Set 12 | prochnookopskaya
# Processing Record 10 of Set 12 | westport
# Processing Record 11 of Set 12 | saurimo
# Processing Record 12 of Set 12 | sao sebastiao do paraiso
# Processing Record 13 of Set 12 | olafsvik
# Processing Record 14 of Set 12 | gabane
# Processing Record 15 of Set 12 | nazarovo
# Processing Record 16 of Set 12 | luanda
# Processing Record 17 of Set 12 | lagos
# Processing Record 18 of Set 12 | toktogul
# Processing Record 19 of Set 12 | alamogordo
# Processing Record 20 of Set 12 | mandera
# Processing Record 21 of Set 12 | cockburn town
# Processing Record 22 of Set 12 | casambalangan
# Processing Record 23 of Set 12 | botwood
# Processing Record 24 of Set 12 | nishihara
# Processing Record 25 of Set 12 | coronel bogado
# Processing Record 26 of Set 12 | mattru
# Processing Record 27 of Set 12 | heihe
# Processing Record 28 of Set 12 | birobidzhan
# Processing Record 29 of Set 12 | aleysk
# Processing Record 30 of Set 12 | kstovo
# Processing Record 31 of Set 12 | labuhan
# Processing Record 32 of Set 12 | maceio
# Processing Record 33 of Set 12 | nemuro
# Processing Record 34 of Set 12 | rumuruti
# Processing Record 35 of Set 12 | north battleford
# Processing Record 36 of Set 12 | hualmay
# Processing Record 37 of Set 12 | lapeer
# Processing Record 38 of Set 12 | krasnoselkup
# Processing Record 39 of Set 12 | ajdabiya
# Processing Record 40 of Set 12 | el tocuyo
# Processing Record 41 of Set 12 | khani
# Processing Record 42 of Set 12 | peniche
# Processing Record 43 of Set 12 | shu
# Processing Record 44 of Set 12 | mooi river
# City not found. Skipping...
# Processing Record 45 of Set 12 | swellendam
# Processing Record 46 of Set 12 | tiznit
# Processing Record 47 of Set 12 | north bend
# Processing Record 48 of Set 12 | shimoda
# Processing Record 49 of Set 12 | inuvik
# Processing Record 50 of Set 12 | shingu
# Processing Record 1 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 2 of Set 13 | tocopilla
# Processing Record 3 of Set 13 | camacha
# Processing Record 4 of Set 13 | inhambane
# Processing Record 5 of Set 13 | khash
# Processing Record 6 of Set 13 | gilbues
# Processing Record 7 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 8 of Set 13 | rodeo
# Processing Record 9 of Set 13 | xining
# Processing Record 10 of Set 13 | pandan
# Processing Record 11 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 12 of Set 13 | starosubkhangulovo
# Processing Record 13 of Set 13 | malanje
# Processing Record 14 of Set 13 | plattsburgh
# Processing Record 15 of Set 13 | lysychovo
# Processing Record 16 of Set 13 | veraval
# Processing Record 17 of Set 13 | phan rang
# City not found. Skipping...
# Processing Record 18 of Set 13 | muros
# Processing Record 19 of Set 13 | shimorskoye
# Processing Record 20 of Set 13 | kropotkin
# Processing Record 21 of Set 13 | xingyi
# Processing Record 22 of Set 13 | roald
# Processing Record 23 of Set 13 | bairiki
# Processing Record 24 of Set 13 | launceston
# Processing Record 25 of Set 13 | ngunguru
# Processing Record 26 of Set 13 | berezovyy
# Processing Record 27 of Set 13 | preobrazhenskaya
# City not found. Skipping...
# Processing Record 28 of Set 13 | santa paula
# Processing Record 29 of Set 13 | mwinilunga
# Processing Record 30 of Set 13 | burns lake
# Processing Record 31 of Set 13 | itarema
# Processing Record 32 of Set 13 | port hedland
# Processing Record 33 of Set 13 | corinto
# Processing Record 34 of Set 13 | vasai
# Processing Record 35 of Set 13 | zakupne
# Processing Record 36 of Set 13 | cherskiy
# Processing Record 37 of Set 13 | puri
# Processing Record 38 of Set 13 | palmer
# Processing Record 39 of Set 13 | madhubani
# Processing Record 40 of Set 13 | mtambile
# Processing Record 41 of Set 13 | itapirapua
# Processing Record 42 of Set 13 | acapulco
# Processing Record 43 of Set 13 | honiara
# Processing Record 44 of Set 13 | santa marta
# Processing Record 45 of Set 13 | lae
# Processing Record 46 of Set 13 | karamea
# City not found. Skipping...
# Processing Record 47 of Set 13 | ottappalam
# Processing Record 48 of Set 13 | wufeng
# Processing Record 49 of Set 13 | stornoway
# Processing Record 50 of Set 13 | storforshei
# Processing Record 1 of Set 14 | dharur
# Processing Record 2 of Set 14 | zeya
# Processing Record 3 of Set 14 | vao
# Processing Record 4 of Set 14 | bati
# Processing Record 5 of Set 14 | peace river
# Processing Record 6 of Set 14 | monywa
# Processing Record 7 of Set 14 | magan
# Processing Record 8 of Set 14 | brae
# Processing Record 9 of Set 14 | hvide sande
# Processing Record 10 of Set 14 | poitiers
# Processing Record 11 of Set 14 | turbat
# Processing Record 12 of Set 14 | nuuk
# Processing Record 13 of Set 14 | bom jesus da lapa
# Processing Record 14 of Set 14 | ballina
# Processing Record 15 of Set 14 | axim
# Processing Record 16 of Set 14 | bakaly
# Processing Record 17 of Set 14 | vagur
# Processing Record 18 of Set 14 | merrill
# Processing Record 19 of Set 14 | belmonte
# Processing Record 20 of Set 14 | kutum
# Processing Record 21 of Set 14 | yomitan
# City not found. Skipping...
# Processing Record 22 of Set 14 | soteapan
# Processing Record 23 of Set 14 | resistencia
# Processing Record 24 of Set 14 | pingliang
# Processing Record 25 of Set 14 | san vicente
# Processing Record 26 of Set 14 | koubia
# Processing Record 27 of Set 14 | wewak
# Processing Record 28 of Set 14 | poronaysk
# Processing Record 29 of Set 14 | mazamari
# Processing Record 30 of Set 14 | makakilo city
# Processing Record 31 of Set 14 | pierre
# Processing Record 32 of Set 14 | slavicin
# Processing Record 33 of Set 14 | saint-georges
# Processing Record 34 of Set 14 | rongcheng
# Processing Record 35 of Set 14 | birao
# Processing Record 36 of Set 14 | dombarovskiy
# Processing Record 37 of Set 14 | andahuaylas
# Processing Record 38 of Set 14 | mirnyy
# Processing Record 39 of Set 14 | morgan city
# Processing Record 40 of Set 14 | rundu
# Processing Record 41 of Set 14 | dzhebariki-khaya
# Processing Record 42 of Set 14 | zhuhai
# Processing Record 43 of Set 14 | atambua
# Processing Record 44 of Set 14 | santa rosalia
# Processing Record 45 of Set 14 | sosnovo-ozerskoye
# Processing Record 46 of Set 14 | sain alto
# Processing Record 47 of Set 14 | chara
# Processing Record 48 of Set 14 | mayor pablo lagerenza
# Processing Record 49 of Set 14 | tres picos
# Processing Record 50 of Set 14 | koumac
# Processing Record 1 of Set 15 | cluses
# Processing Record 2 of Set 15 | tezu
# Processing Record 3 of Set 15 | millau
# Processing Record 4 of Set 15 | majene
# Processing Record 5 of Set 15 | naze
# Processing Record 6 of Set 15 | bay roberts
# Processing Record 7 of Set 15 | saravan
# Processing Record 8 of Set 15 | karamay
# City not found. Skipping...
# Processing Record 9 of Set 15 | vanimo
# Processing Record 10 of Set 15 | dubbo
# Processing Record 11 of Set 15 | omis
# Processing Record 12 of Set 15 | tumba
# Processing Record 13 of Set 15 | buala
# Processing Record 14 of Set 15 | wanaka
# Processing Record 15 of Set 15 | samarai
# Processing Record 16 of Set 15 | chunhuhub
# Processing Record 17 of Set 15 | taltal
# Processing Record 18 of Set 15 | bontang
# Processing Record 19 of Set 15 | tungkang
# City not found. Skipping...
# Processing Record 20 of Set 15 | sayla
# Processing Record 21 of Set 15 | halifax
# Processing Record 22 of Set 15 | rio gallegos
# Processing Record 23 of Set 15 | belaya gora
# Processing Record 24 of Set 15 | dauphin
# Processing Record 25 of Set 15 | battle creek
# Processing Record 26 of Set 15 | kushiro
# Processing Record 27 of Set 15 | puerto escondido
# Processing Record 28 of Set 15 | laurens
# Processing Record 29 of Set 15 | guerrero negro
# Processing Record 30 of Set 15 | komsomolskiy
# Processing Record 31 of Set 15 | thinadhoo
# Processing Record 32 of Set 15 | donetsk
# Processing Record 33 of Set 15 | conceicao da barra
# Processing Record 34 of Set 15 | kegayli
# City not found. Skipping...
# Processing Record 35 of Set 15 | sayyan
# Processing Record 36 of Set 15 | vilhena
# Processing Record 37 of Set 15 | ayan
# Processing Record 38 of Set 15 | jijiga
# Processing Record 39 of Set 15 | garmsar
# Processing Record 40 of Set 15 | salaspils
# Processing Record 41 of Set 15 | ozernovskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 674

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0               Rikitea -23.1203 -134.9692     73.71        78          69
# 1                 Kapaa  22.0752 -159.3190     75.52        81          75
# 2              Ucluelet  48.9329 -125.5528     48.09        88         100
# 3                 Bluff -46.6000  168.3333     44.71        71         100
# 4              Lorengau  -2.0226  147.2712     82.35        77           8
# 5           Pangnirtung  66.1451  -65.7125     40.62        61          66
# 6          San Jeronimo -11.9472  -75.2829     61.16        40           4
# 7             Panzhihua  26.5851  101.7128     69.71        81          24
# 8  Vila Franca Do Campo  37.7167  -25.4333     73.81        71          89
# 9               Margate  51.3813    1.3862     60.96        74          91
#
#    Wind Speed Country           Description
# 0       12.28      PF         broken clouds
# 1        4.00      US  heavy intensity rain
# 2        3.00      CA       overcast clouds
# 3       23.82      NZ       overcast clouds
# 4        7.67      PG             clear sky
# 5        3.13      CA         broken clouds
# 6        1.88      PE             clear sky
# 7        2.26      CN            few clouds
# 8        7.54      PT       overcast clouds
# 9        1.99      GB       overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
